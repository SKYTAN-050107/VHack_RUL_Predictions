# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
import sklearn
from sklearn.metrics import mean_squared_error, r2_score
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import random
import warnings
np.random.seed(34)
warnings.filterwarnings('ignore')
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# Defining features names

# %%
index_names = ['unit_number', 'time_cycles']
setting_names = ['setting_1', 'setting_2', 'setting_3']
sensor_names = ['s_{}'.format(i+1) for i in range(0,21)]
col_names = index_names + setting_names + sensor_names

# %% [markdown]
# Importing train and validation data¶
#
# FD001 subset corresponds to HPC failure of the engine.
#
# Note: train data will be splitted to train/test sets in the modeling part.

# %%
from pathlib import Path

# Resolve the data directory for both possible working directories.

data_dir = Path('../data') if Path('../data').exists() else Path('./data')



dftrain = pd.read_csv(data_dir / 'train_FD001.txt', sep='\s+', header=None, index_col=False, names=col_names)

dfvalid = pd.read_csv(data_dir / 'test_FD001.txt', sep='\s+', header=None, index_col=False, names=col_names)

y_valid = pd.read_csv(data_dir / 'RUL_FD001.txt', sep='\s+', header=None, index_col=False, names=['RUL'])

dfvalid.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dftrain = pd.read_csv('./data/train_FD001.txt',sep='\s+',header=None,index_col=False,names=col_names)
#       2 dfvalid = pd.read_csv('./data/test_FD001.txt',sep='\s+',header=None,index_col=False,names=col_names)
#       3 y_valid = pd.read_csv('./data/RUL_FD001.txt',sep='\s+',header=None,index_col=False,names=['RUL'])
#
# ...
